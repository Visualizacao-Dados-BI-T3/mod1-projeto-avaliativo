# %% [markdown]
# # Opção 1: Acessar dados do FreeSQL através da string de conexão
#
# ## Pré requisitos:
# * fazer conta,
# * verificar email e
# * criar segundo fator de autenticação.
#
# ## Depois de logado:
# * Clicar no botão `Connect with Python (Node, Go..)`
# * Copiar código sugerido para a linguagem Python
# * Pedir adaptação para a IA da sua preferência para colocar no padrão de .ipynb
# * Configurar secrets no Colab

# %%
# 1. Instalar a biblioteca oracledb
# !pip install oracledb -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.0 MB/s eta 0:00:00

# %%
import oracledb
from google.colab import userdata

# 2. Recuperar a senha salva de forma segura nos Secrets do Colab
db_password = userdata.get('DB_PASSWORD')

local_dsn = "tcps://db.freesql.com:2484/26ai_un3c1"

try:
    # 3. Conectar ao banco de dados Oracle
    connection = oracledb.connect(
        user="CIBELLE_COSTA_SCHEMA_U9FPQ",
        password=db_password,
        dsn=local_dsn
    )

    print("Conectado ao Oracle Database com sucesso!")

    # # 4. Executar consulta de teste
    # cursor = connection.cursor()
    # cursor.execute("SELECT * FROM HR.EMPLOYEES")
    # # for result in cursor:
    # #     print("Resultado da consulta:", result)

    # # 5. Fechar conexões
    # cursor.close()
    # connection.close()

except Exception as e:
    print("Erro ao conectar ao banco de dados:", e)
# Out:
# Conectado ao Oracle Database com sucesso!

# %%
import pandas as pd

# %%
df_conection = pd.read_sql("SELECT * FROM HR.EMPLOYEES",connection )

df_conection
# Out:
# /tmp/ipykernel_3911/2815927652.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_conection = pd.read_sql("SELECT * FROM HR.EMPLOYEES",connection )
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL    PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  1.515.555.0100 2013-06-17
# 1            101      Neena      Yang     NYANG  1.515.555.0101 2015-09-21
# 2            102        Lex    Garcia   LGARCIA  1.515.555.0102 2011-01-13
# 3            103  Alexander     James    AJAMES  1.590.555.0103 2016-01-03
# 4            104      Bruce    Miller   BMILLER  1.590.555.0104 2017-05-21
# ..           ...        ...       ...       ...             ...        ...
# 102          202        Pat     Davis    PDAVIS  1.603.555.0167 2015-08-17
# 103          203      Susan    Jacobs   SJACOBS  1.515.555.0168 2012-06-07
# 104          204    Hermann     Brown    HBROWN  1.515.555.0169 2012-06-07
# 105          205    Shelley   Higgins  SHIGGINS  1.515.555.0170 2012-06-07
# 106          206    William     Gietz    WGIETZ  1.515.555.0171 2012-06-07
#
#          JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0       AD_PRES  24000.0             NaN         NaN           90.0
# 1         AD_VP  17000.0             NaN       100.0           90.0
# 2         AD_VP  17000.0             NaN       100.0           90.0
# 3       IT_PROG   9000.0             NaN       102.0           60.0
# 4       IT_PROG   6000.0             NaN       103.0           60.0
# ..          ...      ...             ...         ...            ...
# 102      MK_REP   6000.0             NaN       201.0           20.0
# 103      HR_REP   6500.0             NaN       101.0           40.0
# 104      PR_REP  10000.0             NaN       101.0           70.0
# 105      AC_MGR  12008.0             NaN       101.0          110.0
# 106  AC_ACCOUNT   8300.0             NaN       205.0          110.0
#
# [107 rows x 11 columns]

# %% [markdown]
# # Opção 2: Fazer upload do arquivo no Colab
#
# ## Pontos negativos:
# * A cada novo acesso o arquivo "some" e novo upload deve ser feito,
# * Reduz a reprodutibilidade do código. Um terceiro que acessar apenas o notebook (.ipynb) não terá acesso ao seu arquivo

# %%
df = pd.read_csv("query_1.csv")

df
# Out:
#      EMPLOYEE_ID   FIRST_NAME LAST_NAME  SALARY DEPARTMENT_NAME  \
# 0            200     Jennifer    Whalen    4400  Administration
# 1            201      Michael  Martinez   13000       Marketing
# 2            202          Pat     Davis    6000       Marketing
# 3            114          Den        Li   11000      Purchasing
# 4            115    Alexander      Khoo    3100      Purchasing
# ..           ...          ...       ...     ...             ...
# 102          112  Jose Manuel     Urman    7800         Finance
# 103          113         Luis      Popp    6900         Finance
# 104          205      Shelley   Higgins   12008      Accounting
# 105          206      William     Gietz    8300      Accounting
# 106          178    Kimberely     Grant    7000             NaN
#
#                     JOB_TITLE
# 0    Administration Assistant
# 1           Marketing Manager
# 2    Marketing Representative
# 3          Purchasing Manager
# 4            Purchasing Clerk
# ..                        ...
# 102                Accountant
# 103                Accountant
# 104        Accounting Manager
# 105         Public Accountant
# 106      Sales Representative
#
# [107 rows x 6 columns]

# %% [markdown]
# # Opção 3: Usando o link Raw do arquivo .csv no GitHub
#
# Também é possível carregar o CSV diretamente do GitHub, sem precisar baixar o arquivo para o computador ou fazer upload no Colab. Para mais informações, ver o início da aula do dia 25/09/2026
#
# ## Para isso:
# 1. Acesse o repositório no GitHub.
# 2. Abra a pasta onde está o arquivo .csv.
# 3. Clique no arquivo que deseja utilizar.
# 4. Na página do arquivo, clique no botão Raw.
# 5. Copie o endereço (URL) da página que abriu.
# 6. Cole esse endereço dentro do pd.read_csv().
#
# ### Exemplo:

# %%
url_query_1 = "LINK_RAW_DO_QUERY_01.csv"
df_salarios = pd.read_csv(url_query_1)

url_query_2 = "LINK_RAW_DO_QUERY_02.csv"
df_regioes = pd.read_csv(url_query_2)

# %% [markdown]
# # EDA da `query_1.csv`

# %% [markdown]
# ## 1. Importação da base resultante da query *1*
# Obs.: Left join departamentod e jobs where salary > 0

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/Visualizacao-Dados-BI-T3/mod1-projeto-avaliativo/refs/heads/main/data/query_1.csv")

df1.head() # visualizando as primeiras 5 linhas
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME  SALARY DEPARTMENT_NAME  \
# 0          200   Jennifer    Whalen    4400  Administration
# 1          201    Michael  Martinez   13000       Marketing
# 2          202        Pat     Davis    6000       Marketing
# 3          114        Den        Li   11000      Purchasing
# 4          115  Alexander      Khoo    3100      Purchasing
#
#                   JOB_TITLE
# 0  Administration Assistant
# 1         Marketing Manager
# 2  Marketing Representative
# 3        Purchasing Manager
# 4          Purchasing Clerk

# %%
df1.shape
# Out:
# (107, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EMPLOYEE_ID      107 non-null    int64
#  1   FIRST_NAME       107 non-null    object
#  2   LAST_NAME        107 non-null    object
#  3   SALARY           107 non-null    int64
#  4   DEPARTMENT_NAME  106 non-null    object
#  5   JOB_TITLE        107 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 5.1+ KB

# %%
df1.dtypes
# Out:
# EMPLOYEE_ID         int64
# FIRST_NAME         object
# LAST_NAME          object
# SALARY              int64
# DEPARTMENT_NAME    object
# JOB_TITLE          object
# dtype: object

# %%
df1.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'SALARY', 'DEPARTMENT_NAME',
#        'JOB_TITLE'],
#       dtype='object')

# %% [markdown]
# ## 2. Renomeando as colunas
#
# obs.: consulta a IA e a Tassiana

# %%
df1 = df1.rename(columns={
    "EMPLOYEE_ID": "cod_funcionario",
    "FIRST_NAME": "primeiro_nome",
    "LAST_NAME": "ultimo_nome",
    "SALARY": "salario",
    "DEPARTMENT_NAME": 'nome_depto',
    "JOB_TITLE": 'cargo'
})

df1.columns
# Out:
# Index(['cod_funcionario', 'primeiro_nome', 'ultimo_nome', 'salario',
#        'nome_depto', 'cargo'],
#       dtype='object')

# %% [markdown]
# ## 3. Olhando as estatísticias (numéricas separadas de categóricas)

# %%
df1.describe()
# Out:
#        cod_funcionario       salario
# count       107.000000    107.000000
# mean        153.000000   6461.831776
# std          31.032241   3909.579731
# min         100.000000   2100.000000
# 25%         126.500000   3100.000000
# 50%         153.000000   6200.000000
# 75%         179.500000   8900.000000
# max         206.000000  24000.000000

# %%
df1.describe(include="object")
# Out:
#        primeiro_nome ultimo_nome nome_depto                 cargo
# count            107         107        106                   107
# unique            92         102         11                    19
# top             John      Taylor   Shipping  Sales Representative
# freq               3           2         45                    30

# %% [markdown]
# ## 4. Verificando a presença de valores nulos

# %%
# Dups?
# Nulos
# Tipos corretos
# Os valores fazem sentido?

# %%
df.isnull().sum()
# Out:
# EMPLOYEE_ID        0
# FIRST_NAME         0
# LAST_NAME          0
# SALARY             0
# DEPARTMENT_NAME    1
# JOB_TITLE          0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# cod_funcionario    0
# primeiro_nome      0
# ultimo_nome        0
# salario            0
# nome_depto         1
# cargo              0
# dtype: int64

# %%
df1.isna().mean() * 100
# Out:
# cod_funcionario    0.000000
# primeiro_nome      0.000000
# ultimo_nome        0.000000
# salario            0.000000
# nome_depto         0.934579
# cargo              0.000000
# dtype: float64

# %% [markdown]
# ## 5. Removendo valores nulos (encontrado um nulo na coluna de nome depto)

# %%
df1.shape
# Out:
# (107, 6)

# %%
df1 = df1.dropna(subset=["salario"])

# %%
df.shape
# Out:
# (107, 6)

# %%
df1 = df1.dropna(subset=["nome_depto"])

# %%
df1.shape
# Out:
# (106, 6)

# %% [markdown]
# ## (Opcional) Caso eu quisesse preencher nulos

# %%
df1.shape
# Out:
# (106, 6)

# %%
df1["nome_depto"]
# Out:
# 0      Administration
# 1           Marketing
# 2           Marketing
# 3          Purchasing
# 4          Purchasing
#             ...
# 101           Finance
# 102           Finance
# 103           Finance
# 104        Accounting
# 105        Accounting
# Name: nome_depto, Length: 106, dtype: object

# %%
df1[
    df1["nome_depto"].isna()
]
# Out:
# Empty DataFrame
# Columns: [cod_funcionario, primeiro_nome, ultimo_nome, salario, nome_depto, cargo]
# Index: []

# %%
df1["nome_depto"] = df1["nome_depto"].fillna("Sem Departamento")

# %%
df1[
    df1["nome_depto"] == "Sem Departamento"
]
# Out:
# Empty DataFrame
# Columns: [cod_funcionario, primeiro_nome, ultimo_nome, salario, nome_depto, cargo]
# Index: []

# %% [markdown]
# ## 6. Verificando a presença de valores duplicados

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1[df1.duplicated(subset=["primeiro_nome", "ultimo_nome"])]
# Out:
# Empty DataFrame
# Columns: [cod_funcionario, primeiro_nome, ultimo_nome, salario, nome_depto, cargo]
# Index: []

# %%
df1[df1.duplicated(subset="primeiro_nome")]
# Out:
#      cod_funcionario primeiro_nome ultimo_nome  salario  nome_depto  \
# 21               131         James      Marlow     2500    Shipping
# 24               134       Michael      Rogers     2900    Shipping
# 41               186         Julia   Dellinger     3400    Shipping
# 44               189      Jennifer       Dilly     3600    Shipping
# 46               191       Randall     Perkins     2500    Shipping
# 52               197         Kevin      Feeney     3000    Shipping
# 55               103     Alexander       James     9000          IT
# 61               145          John       Singh    14000       Sales
# 62               146         Karen    Partners    13500       Sales
# 67               151         David   Bernstein     9500       Sales
# 68               152         Peter        Hall     9000       Sales
# 81               165         David         Lee     6800       Sales
# 95               100        Steven        King    24000   Executive
# 100              110          John        Chen     8200     Finance
# 105              206       William       Gietz     8300  Accounting
#
#                     cargo
# 21            Stock Clerk
# 24            Stock Clerk
# 41         Shipping Clerk
# 44         Shipping Clerk
# 46         Shipping Clerk
# 52         Shipping Clerk
# 55             Programmer
# 61          Sales Manager
# 62          Sales Manager
# 67   Sales Representative
# 68   Sales Representative
# 81   Sales Representative
# 95              President
# 100            Accountant
# 105     Public Accountant

# %%
df1.duplicated(subset="primeiro_nome").sum()
# Out:
# np.int64(15)

# %%
# df1['salario'] = pd.to_numeric(df1['salario'])
# df1['data'] = pd.to_datetime(df1['data'], errors=)

# %% [markdown]
#  # EDA da `query_2.csv`
#  Obs.: `WHERE regiao.REGION_NAME IS NOT NULL`

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/Visualizacao-Dados-BI-T3/mod1-projeto-avaliativo/refs/heads/main/data/query_2.csv")

df2.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME  SALARY DEPARTMENT_NAME  \
# 0          100     Steven      King   24000       Executive
# 1          101      Neena      Yang   17000       Executive
# 2          102        Lex    Garcia   17000       Executive
# 3          103  Alexander     James    9000              IT
# 4          104      Bruce    Miller    6000              IT
#
#         STREET_ADDRESS       CITY STATE_PROVINCE              COUNTRY_NAME  \
# 0      2004 Charade Rd    Seattle     Washington  United States of America
# 1      2004 Charade Rd    Seattle     Washington  United States of America
# 2      2004 Charade Rd    Seattle     Washington  United States of America
# 3  2014 Jabberwocky Rd  Southlake          Texas  United States of America
# 4  2014 Jabberwocky Rd  Southlake          Texas  United States of America
#
#   REGION_NAME
# 0    Americas
# 1    Americas
# 2    Americas
# 3    Americas
# 4    Americas

# %%
def diagnostico(tabela):
  "SELECT, INSERT, UPDATE, CREATE -> SQL"
  "PostgreSQL -> banco"
  "def, print, dataframe -> Python"

  print('df.shape:', tabela.shape)

  colunas = tabela.columns.to_list()
  print('df.columns:', colunas)

  # Selecionar colunas numéricas
  numericas = tabela.select_dtypes(include='number')

  # Selecionar colunas categóricas
  categoricas = tabela.select_dtypes(
  include=['object', 'category']
  )

  print('Duplicatas:', tabela.duplicated().sum())

  print(f"\nValores nulos")
  display(tabela.isna().sum())

  print(f"\ndf.describe()")
  display(tabela.describe())

  # verificar
  print("\nModa:")
  for coluna in numericas.columns:
    display(f"{coluna}: {tabela[coluna].mode()[0]}")

  print(f"\nResumo das colunas: tipo, ausentes, percentual ausentes e valores únicos")
  resumo = pd.DataFrame({
'tipo': tabela.dtypes,
'ausentes': tabela.isna().sum(),
'percentual_ausentes': tabela.isna().mean() * 100,
'valores_unicos': tabela.nunique()
})

  for coluna in categoricas.columns:
    print(f"\n{coluna}")
    display(tabela[coluna].value_counts(dropna=False))

  display(resumo)

# %%
diagnostico(df2)
# Out:
# df.shape: (106, 10)
# df.columns: ['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'SALARY', 'DEPARTMENT_NAME', 'STREET_ADDRESS', 'CITY', 'STATE_PROVINCE', 'COUNTRY_NAME', 'REGION_NAME']
# Duplicatas: 0
#
# Valores nulos
# EMPLOYEE_ID        0
# FIRST_NAME         0
# LAST_NAME          0
# SALARY             0
# DEPARTMENT_NAME    0
# STREET_ADDRESS     0
# CITY               0
# STATE_PROVINCE     1
# COUNTRY_NAME       0
# REGION_NAME        0
# dtype: int64
# df.describe()
#        EMPLOYEE_ID        SALARY
# count   106.000000    106.000000
# mean    152.764151   6456.754717
# std      31.083161   3927.798234
# min     100.000000   2100.000000
# 25%     126.250000   3100.000000
# 50%     152.500000   6150.000000
# 75%     179.750000   8950.000000
# max     206.000000  24000.000000
# Moda:
# 'EMPLOYEE_ID: 100'
# 'SALARY: 2500'
# Resumo das colunas: tipo, ausentes, percentual ausentes e valores únicos
#
# FIRST_NAME
# FIRST_NAME
# David        3
# John         3
# Steven       2
# Alexander    2
# James        2
#             ..
# Alyssa       1
# Jonathon     1
# Jack         1
# Charles      1
# Susan        1
# Name: count, Length: 91, dtype: int64
# LAST_NAME
# LAST_NAME
# King          2
# Taylor        2
# Cambrault     2
# Smith         2
# Garcia        1
#              ..
# Hutton        1
# Livingston    1
# Johnson       1
# Jacobs        1
# Partners      1
# Name: count, Length: 102, dtype: int64
# DEPARTMENT_NAME
# DEPARTMENT_NAME
# Shipping            45
# Sales               34
# Finance              6
# Purchasing           6
# IT                   5
# Executive            3
# Marketing            2
# Accounting           2
# Administration       1
# Public Relations     1
# Human Resources      1
# Name: count, dtype: int64
# STREET_ADDRESS
# STREET_ADDRESS
# 2011 Interiors Blvd                         45
# Magdalen Centre, The Oxford Science Park    34
# 2004 Charade Rd                             18
# 2014 Jabberwocky Rd                          5
# 147 Spadina Ave                              2
# Schwanthalerstr. 7031                        1
# 8204 Arthur St                               1
# Name: count, dtype: int64
# CITY
# CITY
# South San Francisco    45
# Oxford                 34
# Seattle                18
# Southlake               5
# Toronto                 2
# Munich                  1
# London                  1
# Name: count, dtype: int64
# STATE_PROVINCE
# STATE_PROVINCE
# California    45
# Oxford        34
# Washington    18
# Texas          5
# Ontario        2
# Bavaria        1
# NaN            1
# Name: count, dtype: int64
# COUNTRY_NAME
# COUNTRY_NAME
# United States of America                                68
# United Kingdom of Great Britain and Northern Ireland    35
# Canada                                                   2
# Germany                                                  1
# Name: count, dtype: int64
# REGION_NAME
# REGION_NAME
# Americas    70
# Europe      36
# Name: count, dtype: int64
#                    tipo  ausentes  percentual_ausentes  valores_unicos
# EMPLOYEE_ID       int64         0             0.000000             106
# FIRST_NAME       object         0             0.000000              91
# LAST_NAME        object         0             0.000000             102
# SALARY            int64         0             0.000000              58
# DEPARTMENT_NAME  object         0             0.000000              11
# STREET_ADDRESS   object         0             0.000000               7
# CITY             object         0             0.000000               7
# STATE_PROVINCE   object         1             0.943396               6
# COUNTRY_NAME     object         0             0.000000               4
# REGION_NAME      object         0             0.000000               2

# %%
df_funcao = diagnostico(df1)
# Out:
# df.shape: (106, 6)
# df.columns: ['cod_funcionario', 'primeiro_nome', 'ultimo_nome', 'salario', 'nome_depto', 'cargo']
# Duplicatas: 0
#
# Valores nulos
# cod_funcionario    0
# primeiro_nome      0
# ultimo_nome        0
# salario            0
# nome_depto         0
# cargo              0
# dtype: int64
# df.describe()
#        cod_funcionario       salario
# count       106.000000    106.000000
# mean        152.764151   6456.754717
# std          31.083161   3927.798234
# min         100.000000   2100.000000
# 25%         126.250000   3100.000000
# 50%         152.500000   6150.000000
# 75%         179.750000   8950.000000
# max         206.000000  24000.000000
# Moda:
# 'cod_funcionario: 100'
# 'salario: 2500'
# Resumo das colunas: tipo, ausentes, percentual ausentes e valores únicos
#
# primeiro_nome
# primeiro_nome
# John           3
# David          3
# Jennifer       2
# Karen          2
# James          2
#               ..
# Daniel         1
# Ismael         1
# Jose Manuel    1
# Luis           1
# Shelley        1
# Name: count, Length: 91, dtype: int64
# ultimo_nome
# ultimo_nome
# Taylor       2
# Cambrault    2
# King         2
# Smith        2
# Davis        1
#             ..
# Sciarra      1
# Urman        1
# Popp         1
# Higgins      1
# Gietz        1
# Name: count, Length: 102, dtype: int64
# nome_depto
# nome_depto
# Shipping            45
# Sales               34
# Purchasing           6
# Finance              6
# IT                   5
# Executive            3
# Marketing            2
# Accounting           2
# Administration       1
# Public Relations     1
# Human Resources      1
# Name: count, dtype: int64
# cargo
# cargo
# Sales Representative               29
# Shipping Clerk                     20
# Stock Clerk                        20
# Programmer                          5
# Accountant                          5
# Sales Manager                       5
# Purchasing Clerk                    5
# Stock Manager                       5
# Administration Vice President       2
# Administration Assistant            1
# Marketing Manager                   1
# Marketing Representative            1
# Public Relations Representative     1
# Purchasing Manager                  1
# Human Resources Representative      1
# President                           1
# Finance Manager                     1
# Accounting Manager                  1
# Public Accountant                   1
# Name: count, dtype: int64
#                    tipo  ausentes  percentual_ausentes  valores_unicos
# cod_funcionario   int64         0                  0.0             106
# primeiro_nome    object         0                  0.0              91
# ultimo_nome      object         0                  0.0             102
# salario           int64         0                  0.0              58
# nome_depto       object         0                  0.0              11
# cargo            object         0                  0.0              19

# %% [markdown]
# # TO DO
#
# ## Quem não executou GROUP BY no SQL deve fazer no notebook para responder às perguntas do vídeo/insights do README
#
# ### Exemplo de agregação:

# %%
# group by

df1.groupby("cargo")["salario"].sum()
# Out:
# cargo
# Accountant                          39600
# Accounting Manager                  12008
# Administration Assistant             4400
# Administration Vice President       34000
# Finance Manager                     12008
# Human Resources Representative       6500
# Marketing Manager                   13000
# Marketing Representative             6000
# President                           24000
# Programmer                          28800
# Public Accountant                    8300
# Public Relations Representative     10000
# Purchasing Clerk                    13900
# Purchasing Manager                  11000
# Sales Manager                       61000
# Sales Representative               243500
# Shipping Clerk                      64300
# Stock Clerk                         55700
# Stock Manager                       36400
# Name: salario, dtype: int64
